# %%
import requests as r
import json
#query = "Please provide all data request"
#query = "Please provide a copy of all intervenor data requests submitted to SoCalGas in this proceeding and SoCalGas’ responses to those requests."
query = "data warehouse"
#query = "Does SDG&E keep records of the number of small businesses located in California which provide goods or services to SDG&E?"
#query = "please state the current annual right-of-way cost that SoCalGas pays to the Morongo tribe"
#query = "Please provide a table showing SoCalGas's proposed total net revenue requirements for 1998 and 1980, approved revenue requirements for each year from 2014 through 2018, and actual total expenditures for 2014 through 2017. "
#query = "Decarbonizing Pipeline Gas"
#query = "advocacy", "object"

POST_JSON = {
    'input_query': "data warehouse"
}

r.post('http://127.0.0.1:5000/api', json=POST_JSON).json()
# Out:
# {'request': {'0': 'Referring to SCG’s testimony, page MFL-8, lines 9-19, please explain the reason for SCG’s request in filling two existing vacancies as SCG has already requested for two additional employees in Gas Acquisition on SCG’s testimony, SCG-09, page ITC-5, lines 20-21, in Sempra’s 2016 GRC, in which Gas Procurement O&M costs for two FTE vacancies were adopted in the last decision, D.16-06-054.',
#   '1': 'Referring to SCG’s testimony, page MFL-8, lines 13-15, SoCalGas states, “We expect these vacancies to be filled by 2017 and have scheduled these vacancies to reflect the partial filling of existing vacancies in 2017 up to full staffing levels in 2018 and 2019.” Please indicate whether SoCalGas has filled, or partially filled, the existing vacancies in 2017. If yes, provide supporting documentation which reflects this and provides details such as when the vacancy was filled and at what annual salary. If no, explain why the full or partial filling of existing vacancies in 2017 has not occurred yet.',
#   '2': 'Which are the two air districts in SoCalGas’ service territory that are in extreme nonattainment? (SCG-01-R at JBL-5). How many and what type of customers does SoCalGas serve in each air district?',
#   '3': 'For each year since 2012, provide the names and titles of the members of the SoCalGas Executive Safety committee.',
#   '4': '“The purpose of the [SoCalGas Executive Safety] committee is to reinforce key safety tenets and have an open dialogue to discuss safety concerns and to develop actionable plans to address the issues or concerns as warranted.” (SCG-01-R at JBL-6). In each year since 2012, what have been the “actionable plans” developed as a result of these committee meetings?',
#   '5': 'For each year since 2012, provide the names and titles of the members of the SDGE Executive Safety Council.',
#   '6': '. “Comprised of top leadership, the [SDGE Executive Safety] council meets quarterly to engage directly with front-line employees and supervisors to listen and reinforce key safety tenets and have an open dialogue on safety issues, performance and culture.” (SDGE-01 at CAW-5). In each year since 2012, what have been the actionable plans developed as a result of these council meetings?',
#   '7': 'Please provide copies of the National Safety Council assessment for 2013 and 2016 for SoCalGas and SDGE.',
#   '8': 'In the 2016 NSC assessment of SoCalGas, what were the three program categories that showed increases in percentile scores over 2013? Did any categories decrease in score? (SCG-01-R at JBL-7).',
#   '9': 'In the 2016 NSC assessment of SDGE, what program categories showed the greatest decrease in percentile scores over 2013? Did any categories increase in score? (SDGE-01 at CAW-6).',
#   '10': 'What are the specific ways that SoCalGas is expanding communications and outreach activities to low-income customer and disadvantaged communities? (SCG-01-R at JBL15).',
#   '11': 'How do SoCalGas and SDGE define the phrase “reasonable rates” as used throughout testimony? (e.g. SCG-01-R at JBL-1, JBL-3; SDGE-01 at CAW-1, CAW-7).',
#   '12': 'Does SoCalGas currently have a long-term pipeline replacement program? Please provide a copy.',
#   '13': 'Around October 2017, SoCalGas experienced several pipeline outages near Newberry Springs. Please provide a copy of any preliminary root cause analyses (RCA) for the incidents.',
#   '14': 'Please discuss the impacts from pipeline outages on SoCalGas’ operations with regards to reliability and safety.',
#   '15': 'On Page 29 of Exhibit SCG-14, Ms. Martinez stated the followings: Through the TIMP, SoCalGas continually evaluates the pipeline system and proactively takes action through inspections, replacements, and other remediation activities to improve the safety and reliability of the system. Please explain how SoCalGas has incorporated or will incorporate the information obtained from similar outages to “improve the safety and reliability of the system.',
#   '16': 'In an effort to gain a better understanding of SoCalGas’ pipeline replacement program, which was discussed in Exhibit SCG-15, please explain how these would fit into the replacement programs if the outages did not occur.',
#   '17': 'Please identify the programs and projects proposed in this GRC application that would prevent the failure of infrastructures, which may have an impact on reliability and safety such as the October 2017 incident.',
#   '18': 'SCG-43, page KN-ii, states that "Southern California Gas Company (SoCalGas) proposes $2,989,477,000 for its Test Year (TY) 2019 revenue requirement. a. Please provide a table showing SoCalGas\'s proposed total revenue requirements for 2020 and 2021, approved revenue requirements for each year from 2014 through 2018, and actual total expenditures for 2014 through 2017.',
#   '19': 'SDG&E-01, page CAW-7, describes SDG&E\'s TY2019 revenue requirement: "SDG&E’s GRC Application requests that the Commission authorize a combined $2.199 billion revenue requirement ($433 million gas and $1.766 billion electric), to be effective January 1, 2019. If approved, this revenue requirement would be an increase of $218 million over the asexpected authorized 2018 revenue requirement." a. Please provide a table showing SDG&E\'s proposed total revenue requirements for 2020 and 2021, approved revenue requirements for each year from 2014 through 2018, and actual total expenditures for 2014 through 2017.',
#   '20': 'Please provide redlined copies of each page of the originally filed testimony showing the changes made in the December 20, 2017 revisions',
#   '21': 'Please confirm that Ex. SDG&E-45 should have been titled Ex. SCG-46, and vice versa.',
#   '22': 'Provide 2017 insurance premiums paid as of December 28, 2017',
#   '23': 'Provide 2018 renewal premiums. If they are not available, when will they be?',
#   '24': 'Page NKC-11 line 17-18 says “coverage to Sempra companies outside of California, for statutory benefits payable under the workers’ compensation statutes of the various states.” What other business units are included other than SDG&E and SCG?',
#   '25': 'Page NKC-3, Table NKC-2 is a property insurance summary, provide a breakdown of the increases shown for each line of coverage',
#   '26': 'Page NKC-6 line 10/11 references forecasts provided by Marsh and OIL, provide Marsh and OIL forecasts.',
#   '27': 'Page NKC-6 line 20-22 says “this arrangement results in lower costs…”. Provide support for lower cost',
#   '28': 'Page NKC-8 table NKC-6, what was paid in 2017? Provide premiums paid for 2018 and if they are not available, state when they will be.',
#   '29': 'Page NKC-8 Table NKC-6, why is line B-2 Fire go up $14.6 million? If numbers are in workpapers, please break them out.',
#   '30': 'Page NKC-9 Table 8, why does SDG&E have such a high allocation percentage versus SCG?',
#   '31': 'Workpaper page 52, break out the summary box into components. Define the “Payroll” piece and how much that contributes.',
#   '32': 'Provide proof the wildfire premiums are increasing.',
#   '33': 'Page NKC-16 asks for a new balancing account. How were you paying for liability premiums previously? Why a two-way balancing account versus a one-way?',
#   '34': '. Provide list of policy renewal dates.',
#   '35': 'Workpaper page 38, provide additional information regarding the summary box.',
#   '36': 'In her testimony at the evidentiary hearing held on July 9, 2018, Ms. Orozco-Mejia testified that this general rate case includes a request for funding for surveys of unprotected steel pipelines not located in a business district every three years. July 9, 2018 Transcript (A.17-10- 007, A.17-10-008) at 516. Please state the forecasted cost per year associated with this survey.',
#   '37': 'In her testimony at the evidentiary hearing held on July 9, 2018, Ms. Orozco-Mejia testified that this general rate case includes a request for funding for annual surveys of unprotected steel pipelines located in a business district every three years. July 9, 2018 Transcript (A.17-10-007, A.17-10-008) at 515. Please state the forecasted cost per year associated with this survey.',
#   '38': 'In Table 1 of its 2018 Leak Abatement Compliance Plan, Southern California Gas states that funding for annual surveys of adlyl A plastic pipelines is included in this General Rate Case. Please state the forecasted cost per year associated with this survey',
#   '39': 'Please provide a copy of all intervenor data requests submitted to SoCalGas in this proceeding and SoCalGas’ responses to those requests. Please treat this request as ongoing',
#   '40': 'Please provide a copy of all intervenor data requests submitted to SoCalGas in this proceeding and SoCalGas’ responses to those requests.',
#   '41': 'So consider this a formal data request for a single spreadsheet per utility that identifies all GRC proposed spending related to “safety projects” (i.e., costs associated with both Controls and proposed mitigations for identified safety risks from the RAMP), plus any other spending identified as “safety” related. This will help us segregate safety related spending, impacts and identify any projects that may apply to more than one risk (at least we hope it does that).',
#   '42': 'In Volume SDGE-02/SCG-02, Appendix A.1 (Pages DD-A.1-1 – DD.A.1-4 there are tables that Map the RAMP Risk updates to portions of utility testimony scattered through multiple volumes. Please compile all the relevant portions cited into a single document compendium, for easier reference.',
#   '43': 'Please provide copies of the SDG&E and SoCalGas Safety Barometer Reports.',
#   '44': 'Please provide SDG&E’s and SoCalGas’s responses to the Master Data Request.',
#   '45': 'Page RDP-A-34 of SCG-15 states, “To date, SoCalGas and SDG&E have experienced one test failure out of a total of 53 separate tests totaling 90 miles.” Please identify the line and segment where this test failure occurred, the date on which it occurred, and the test medium.',
#   '46': 'Please provide the number of vendors which provide goods or services to SDG&E',
#   '47': 'Does SDG&E keep records of the number of small businesses located in California which provide goods or services to SDG&E?',
#   '48': 'If SDG&E keeps records of the number of small businesses located in California which provide goods or services to SDG&E, how many of these small businesses provide goods or services to SDG&E?',
#   '49': 'How many small businesses does SDG&E provide electric service to?',
#   '50': 'How many Schedule A (small commercial customers either TOU or otherwise) does SDG&E provide service to?',
#   '51': 'How many California small businesses provide services on behalf of the Tier 1 contractors that SDG&E uses?',
#   '52': 'Please provide the number of vendors which provide goods or services to SoCalGas.',
#   '53': 'Does SoCalGas keep records of the number of small businesses located in California which provide goods or services to SoCalGas?',
#   '54': 'If SoCalGas keeps records of the number of small businesses located in California which provide goods or services to SoCalGas, how many of these small businesses provide goods or services to SoCalGas?',
#   '55': 'How many small businesses does SoCalGas provide gas service to?',
#   '56': 'How many small businesses provide services on behalf of the Tier 1 contractors that SoCalGas uses?',
#   '57': 'In Decision 17-12-014 the commission authorized SDG&E to return $3.023 million in 2017 to small businesses, how does SDG&E plan to return this money?',
#   '58': 'As a follow up to the previous question, please provide a detailed example of how the money is being returned?',
#   '59': 'In Decision 17-12-014 the commission authorized SDG&E to return $3.750 million in 2018 to small businesses, how does SDG&E plan to return this money?',
#   '60': 'Is there any testimony regarding the return of the GHG credits to small businesses?',
#   '61': 'If SDG&E considers the return of GHG credits to not be part of the GRC, why is SDG&E taking this position?',
#   '62': 'On what basis is SDG&E placing the SONGS Unit 1 Offsite Spent Fuel Storage Costs in an ERRA proceeding rather than in this GRC?',
#   '63': 'Has someone from ORA or the Commission approved a long-term plan for spent fuel storage from SONGS ?',
#   '64': 'For each pipeline listed on DRH-17, lines 8-10, please state the current annual right-of-way cost that SoCalGas pays to the Morongo tribe.',
#   '65': 'Please provide an estimate of the cost to complete an engineering study (in terms of number and type of full-time employees and the length of time required to complete the study) of the cost of rerouting each of the pipelines listed on DRH-17, lines 8-10, in order to completely avoid the Morongo reservation.',
#   '66': 'Please provide all workpapers that are in excel format. Presently, UCAN only has access to the PDF workpapers that were served with the application and that are on the SDG&E proceedings page website.',
#   '67': 'In its response to Question 3 of DR Sierra Club/UCS-SCG-05, SoCal Gas states that the Decarbonizing Pipeline Gas report was “categorized as GRC ratepayer funded operations and maintenance (O&M) expense.” a. Please explain why operations and maintenance funds were used to pay for this report. b. Please provide the criteria used by SoCalGas to determine if an expenditure qualifies as an appropriate operations and maintenance expense.',
#   '68': 'With respect to SoCalGas’ request for funding to construct new and upgrade existing natural gas vehicle fueling stations for use by SoCalGas fleet vehicles, discussed in Exh. SCG-23: a. Please provide, in dollars per MMBtu, the cost passed on to ratepayers for the natural gas consumed at these fueling stations to fuel SoCalGas’ vehicle fleet. b. What is the basis for this cost?',
#   '69': 'On April 20, 2018 SoCalGas Regional Vice President George Minter published an opinion piece in the Sacramento Bee titled, “Most of us can’t afford to go all-electric. Here’s a fairer way to curb climate change,” which is available at http://www.sacbee.com/opinion/california-forum/article209189564.html. Were any costs associated with preparation of this opinion piece or its placement with the newspaper borne by ratepayers? If so, please provide the category of ratepayer funded cost used to prepare the article.',
#   '70': 'Please provide executable versions of all rebuttal filings and supporting workpapers in native format with all formulas intact.',
#   '71': 'Please provide a copy of any confidential portions of the rebuttal testimony or material referenced in the rebuttal testimony or workpapers.',
#   '72': 'Has SoCalGas performed any analysis or comparison of its natural gas transportation rates with rates of other natural gas distribution companies operating in the United States? If so, please provide all documents related to such analysis. If no analysis has been performed, explain why SoCalGas does not believe it is relevant to perform such analysis.',
#   '73': 'Does SoCalGas possess any analysis or comparison of its natural gas transportation rates with rates of other natural gas distribution companies operating in the United States? If so, please provide all documents in SoCalGas’s possession related to such analysis.',
#   '74': 'Has SoCalGas performed any analysis of the impact of 2019 GRC rate impacts on industrial natural gas end-use customers generally? On industrial transmission customers more specifically? If so, please provide all documents related to such analysis.',
#   '75': 'At Page 7 of the March 8, 2017 Staff Report on Risk and Safety Aspects of Risk Assessment and Mitigation Phase Report of San Diego Gas & Electric Company and Southern California Gas Company, Investigation 16-10-015 and I.16-10-016, Staff state: The following should be considered for improvement in the GRC presentation and workpapers: • In the RSE, use plausible comparisons that connect causal relationships to information provided for making a sound decision on whether the increase in spending would be reasonable and the incident rate reductions possible. • More thoroughly outline plans for enhancing existing mitigations, and provide more information to sufficiently describe how enhancements differ and improve baseline (Control) activities with an estimate of risk reduction. • Improve the correlation of the RSE to the baseline risks and the proposed risk mitigations in order for the RSE to be used as intended. • Address the requirement to provide an RSE for the alternative mitigation programs, and work on presenting reasonable and viable alternatives and provide sufficient explanation of alternatives and their potential for risk reduction. The testimony of Diana Day discusses the Staff Report. Please provide further citations to testimony that demonstrates how SoCalGas incorporated these suggestions in the following chapters: a. SCG-05 Gas System Integrity- Omar Rivera b. SCG-06 Gas Transmission Operation- Elizabeth Musich c. SCG-07 Gas Transmission- Elizabeth Musich d. SCG-09 Underground Storage- Neil Navin e. SCG-14 Pipeline Integrity for Transmission and Distribution – Maria Martinez',
#   '76': 'With respect to the Applicants’ response to SCGC-SEU-02, Q.2.8.1, is the information identifying the entity that procures gas on behalf of core customers uploaded to the Data Warehouse?',
#   '77': 'If the answer to the previous question is “yes,” please state how frequently the information identifying the entity that procures gas on behalf of core customers is uploaded to the Data Warehouse.',
#   '78': 'With respect to the response to SCGC-SEU-02, Q.2.8.3, please state what data constitutes “master data”, defining each category that is included in the data uploaded to the Data Warehouse from the CIS database on a daily basis.',
#   '79': 'Please confirm that the data from the CIS database that is uploaded to the Data Warehouse can be queried simultaneously with the AM interval data within the Data Warehouse.',
#   '80': 'Please confirm that the MDMS data set contains the MTU identifier in addition to the hourly meter data',
#   '81': 'Does the MDMS data set that is uploaded daily to the Data Warehouse contain all of the hourly metering history that is available for a given MTU identifier in addition to the hourly metering data for that MTU identifier for the previous metering day?',
#   '82': 'If the answer to the previous question is “no,” please define the portion of the metering history that is available for a given MTU identifier.',
#   '83': 'In terms of a simultaneous query of the CIS data that has been uploaded to the Data Warehouse and the AMI data for the previous metering day that has been uploaded to the Data Warehouse, how long would it take to run a query within the Data Warehouse for the entire approximately 5.9 million customers that selects the identity of each core customer’s gas provider from the CIS data and selects the AMI data for the previous metering day and writes the MTU identifier, the identity of the gas provider, and the total of the hourly metering data for the previous day to a new database within the Data Warehouse converting the hourly reads of cubic feet to therms and compiling the results by the identity of the gas providers, e.g., Gas Acquisition, CTA #1, CTA #2, etc., so a total daily metered use for the previous metering day is determined for each gas provider?',
#   '84': 'Would the time required to run the query scale down linearly, e.g., if 40 percent of the customers were included in the query described previously would the time required be approximately 40 percent of the time required for the previously described query?',
#   '85': 'Please explain all the elements contributing to the difference in the level of the BTS rate reflected in two of the Tables in the updated April 6, 2018 SoCalGas testimony (SCG-46- 2R)(Chaudhury) (attached). First, please explain all the variables contributing to the difference between the "present rate" in Table ISC-03 ($0.30592 per dth/day) and the "present rate" in Appendix A, Table ISC-02-2018 ($0.26353). Second, please explain all the variables contributing to the difference between the "proposed 2019 rate" in Table ISC-03 ($0.49954 per dth/day) and the "proposed 2019 rate" in Appendix A, Table ISC-02-2018 ($0.37001).',
#   '86': 'Please provide all workpapers that show how the proposed 2019 BTS rate in Appendix A, Table ISC-02-2018 was derived, including all changes in the variables in the calculation of the proposed 2019 BTS rate, as compared to the variables in the calculation of the proposed 2019 BTS rate in Table ISC-03 .'},
#  'sim': {'0': -0.02326115220785141,
#   '1': 0.0035103484988212585,
#   '2': -0.06594975292682648,
#   '3': 0.014734702184796333,
#   '4': -0.03702829033136368,
#   '5': 0.01850658655166626,
#   '6': -0.015246275812387466,
#   '7': 0.08112973719835281,
#   '8': -0.07854273915290833,
#   '9': -0.0680960863828659,
#   '10': -0.049683380872011185,
#   '11': -0.13439972698688507,
#   '12': 0.12448578327894211,
#   '13': 0.11987440288066864,
#   '14': 0.07789137214422226,
#   '15': 0.024574827402830124,
#   '16': 0.00506630539894104,
#   '17': 0.1104002594947815,
#   '18': 0.010059315711259842,
#   '19': -0.013672199100255966,
#   '20': 0.11373340338468552,
#   '21': 0.025821352377533913,
#   '22': 0.08391979336738586,
#   '23': 0.09398070722818375,
#   '24': -0.02346000075340271,
#   '25': 0.08170060813426971,
#   '26': 0.0940130352973938,
#   '27': 0.09976505488157272,
#   '28': 0.10354521125555038,
#   '29': 0.12449859082698822,
#   '30': -0.02287466824054718,
#   '31': 0.04643629491329193,
#   '32': 0.06884053349494934,
#   '33': 0.04631206765770912,
#   '34': 0.06085766851902008,
#   '35': 0.07448627799749374,
#   '36': 0.010005076415836811,
#   '37': 0.010124310851097107,
#   '38': 0.02976595237851143,
#   '39': 0.33440160751342773,
#   '40': 0.3518185019493103,
#   '41': 0.15109367668628693,
#   '42': 0.04368511214852333,
#   '43': 0.08340176939964294,
#   '44': 0.4456685781478882,
#   '45': 0.09585846960544586,
#   '46': 0.06633935123682022,
#   '47': -0.018622245639562607,
#   '48': -0.014760177582502365,
#   '49': -0.025858772918581963,
#   '50': 0.0065429434180259705,
#   '51': -0.012911319732666016,
#   '52': 0.06941733509302139,
#   '53': -0.011261653155088425,
#   '54': -0.00825013592839241,
#   '55': 0.05668212100863457,
#   '56': 0.0002720467746257782,
#   '57': -0.05253615975379944,
#   '58': 0.307939350605011,
#   '59': -0.05253615975379944,
#   '60': -0.0628862977027893,
#   '61': -0.05400143936276436,
#   '62': -0.004134012386202812,
#   '63': 0.005360908806324005,
#   '64': 0.06200869008898735,
#   '65': -0.020105771720409393,
#   '66': 0.11262586712837219,
#   '67': 0.025679901242256165,
#   '68': 0.02817258983850479,
#   '69': -0.02814493514597416,
#   '70': 0.14716923236846924,
#   '71': 0.1254352629184723,
#   '72': -0.059103064239025116,
#   '73': -0.027892857789993286,
#   '74': -0.000939585268497467,
#   '75': -0.0074230218306183815,
#   '76': 0.8907415866851807,
#   '77': 0.8366193771362305,
#   '78': 0.9596101641654968,
#   '79': 0.9846231341362,
#   '80': 0.9300195574760437,
#   '81': 0.9817494750022888,
#   '82': 0.7441240549087524,
#   '83': 0.9058554172515869,
#   '84': -0.054264962673187256,
#   '85': -0.010018626227974892,
#   '86': 0.006376814097166061},
#  'url': {'0': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/ORA-DR-003_FH2_C_final_P.pdf',
#   '1': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/ORA-DR-003_FH2_C_final_P.pdf',
#   '2': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/NDC-SEU-002_Final.pdf',
#   '3': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/NDC-SEU-002_Final.pdf',
#   '4': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/NDC-SEU-002_Final.pdf',
#   '5': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/NDC-SEU-002_Final.pdf',
#   '6': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/NDC-SEU-002_Final.pdf',
#   '7': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/NDC-SEU-002_Final.pdf',
#   '8': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/NDC-SEU-002_Final.pdf',
#   '9': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/NDC-SEU-002_Final.pdf',
#   '10': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/NDC-SEU-002_Final.pdf',
#   '11': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/NDC-SEU-002_Final.pdf',
#   '12': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/OSA-SEU-005_Q1-6.pdf',
#   '13': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/OSA-SEU-005_Q1-6.pdf',
#   '14': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/OSA-SEU-005_Q1-6.pdf',
#   '15': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/OSA-SEU-005_Q1-6.pdf',
#   '16': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/OSA-SEU-005_Q1-6.pdf',
#   '17': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/OSA-SEU-005_Q1-6.pdf',
#   '18': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/CFC-SEU-007_Final.pdf',
#   '19': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/CFC-SEU-007_Final.pdf',
#   '20': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/CUE-SEU-DR-04_Q_241_Final.pdf',
#   '21': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/CUE%20DR-01.pdf',
#   '22': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/ORA-SDGESCG-ORAL-DR-002-LL%20Final.pdf',
#   '23': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/ORA-SDGESCG-ORAL-DR-002-LL%20Final.pdf',
#   '24': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/ORA-SDGESCG-ORAL-DR-002-LL%20Final.pdf',
#   '25': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/ORA-SDGESCG-ORAL-DR-002-LL%20Final.pdf',
#   '26': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/ORA-SDGESCG-ORAL-DR-002-LL%20Final.pdf',
#   '27': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/ORA-SDGESCG-ORAL-DR-002-LL%20Final.pdf',
#   '28': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/ORA-SDGESCG-ORAL-DR-002-LL%20Final.pdf',
#   '29': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/ORA-SDGESCG-ORAL-DR-002-LL%20Final.pdf',
#   '30': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/ORA-SDGESCG-ORAL-DR-002-LL%20Final.pdf',
#   '31': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/ORA-SDGESCG-ORAL-DR-002-LL%20Final.pdf',
#   '32': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/ORA-SDGESCG-ORAL-DR-002-LL%20Final.pdf',
#   '33': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/ORA-SDGESCG-ORAL-DR-002-LL%20Final.pdf',
#   '34': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/ORA-SDGESCG-ORAL-DR-002-LL%20Final.pdf',
#   '35': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/ORA-SDGESCG-ORAL-DR-002-LL%20Final.pdf',
#   '36': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/EDF-DR5%20Q1-3%20Final.pdf',
#   '37': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/EDF-DR5%20Q1-3%20Final.pdf',
#   '38': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/EDF-DR5%20Q1-3%20Final.pdf',
#   '39': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/CLB-SCG-001.pdf',
#   '40': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/CLB-SCG-002.pdf',
#   '41': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SED-DR-1.pdf',
#   '42': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SED-DR-2%20final.pdf',
#   '43': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SED-DR-3%20final-Public.pdf',
#   '44': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/TURN_DR-01%20Final.pdf',
#   '45': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/TURN_DR-02%20FINAL.PDF',
#   '46': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SBUA-SEU-DR-001_Combined.pdf',
#   '47': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SBUA-SEU-DR-001_Combined.pdf',
#   '48': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SBUA-SEU-DR-001_Combined.pdf',
#   '49': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SBUA-SEU-DR-001_Combined.pdf',
#   '50': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SBUA-SEU-DR-001_Combined.pdf',
#   '51': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SBUA-SEU-DR-001_Combined.pdf',
#   '52': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SBUA-SEU-DR-001_Combined.pdf',
#   '53': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SBUA-SEU-DR-001_Combined.pdf',
#   '54': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SBUA-SEU-DR-001_Combined.pdf',
#   '55': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SBUA-SEU-DR-001_Combined.pdf',
#   '56': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SBUA-SEU-DR-001_Combined.pdf',
#   '57': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SBUA-SEU-DR-001_Combined.pdf',
#   '58': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SBUA-SEU-DR-001_Combined.pdf',
#   '59': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SBUA-SEU-DR-001_Combined.pdf',
#   '60': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SBUA-SEU-DR-001_Combined.pdf',
#   '61': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SBUA-SEU-DR-001_Combined.pdf',
#   '62': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SBUA-SEU-DR-001_Combined.pdf',
#   '63': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SBUA-SEU-DR-001_Combined.pdf',
#   '64': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/TURN-SCGC-DR-09_Final.pdf',
#   '65': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/TURN-SCGC-DR-09_Final.pdf',
#   '66': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/UCAN%20DR-01%20Q%201%20final.pdf',
#   '67': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SIERRA_CLUB-UCS-SCG-008-Final.pdf',
#   '68': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SIERRA_CLUB-UCS-SCG-008-Final.pdf',
#   '69': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SIERRA_CLUB-UCS-SCG-008-Final.pdf',
#   '70': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/IS%20DR%2010%20FINAL.PDF',
#   '71': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/IS%20DR%2010%20FINAL.PDF',
#   '72': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/IS%20DR%2010%20FINAL.PDF',
#   '73': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/IS%20DR%2010%20FINAL.PDF',
#   '74': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/IS%20DR%2010%20FINAL.PDF',
#   '75': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/IS%20DR%2010%20FINAL.PDF',
#   '76': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SCGC-SEU-003_Final.pdf',
#   '77': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SCGC-SEU-003_Final.pdf',
#   '78': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SCGC-SEU-003_Final.pdf',
#   '79': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SCGC-SEU-003_Final.pdf',
#   '80': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SCGC-DR-004-Final.pdf',
#   '81': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SCGC-DR-004-Final.pdf',
#   '82': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SCGC-DR-004-Final.pdf',
#   '83': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SCGC-DR-004-Final.pdf',
#   '84': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/SCGC-DR-004-Final.pdf',
#   '85': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/Shell-Tenaska-DR-001Final-.pdf',
#   '86': 'https://www.socalgas.com/regulatory/documents/a-17-10-008/Shell-Tenaska-DR-001Final-.pdf'}}
